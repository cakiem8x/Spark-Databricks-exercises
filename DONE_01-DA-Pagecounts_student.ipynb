# %% [markdown]
# ![Wikipedia/Spark Logo](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark.png)
#
# #### Analyzing Traffic Patterns to Wikimedia Projects
#
# **Objective:**
# Study traffic patterns to all English Wikimedia projects from the past hour
#
# **Time to Complete:**
# 30 mins
#
# **Data Source:**
# Last hour's English Projects Pagecounts (~35 MB compressed parquet file)
#
# **Business Questions:**
#
# * Question # 1) How many different English Wikimedia projects saw traffic in the past hour?
# * Question # 2) How much traffic did each English Wikimedia project get in the past hour?
# * Question # 3) What were the 25 most popular English articles in the past hour?
# * Question # 4) How many requests did the "Apache Spark" article recieve during this hour?
# * Question # 5) Which Apache project received the most requests during this hour?
# * Question # 6) What percentage of the 5.1 million English articles were requested in the past hour?
# * Question # 7) How many total requests were there to English Wikipedia Desktop edition in the past hour?
# * Question # 8) How many total requests were there to English Wikipedia Mobile edition in the past hour?
#
# **Technical Accomplishments:**
# - Create a DataFrame
# - Print the schema of a DataFrame
# - Use the following Transformations: `select()`, `distinct()`, `groupBy()`, `sum()`, `orderBy()`, `filter()`, `limit()`
# - Use the following Actions: `show()`, `count()`
# - Learn about Wikipedia Namespaces
#
# **NOTE**
# Please run this notebook in a Spark 2.0 cluster.

# %% [markdown]
# ####![Wikipedia Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/logo_wikipedia_tiny.png) **Introduction: Wikipedia Pagecounts**

# %% [markdown]
# Until August, 2016, the Wikimedia Foundation poublished hourly page count statistics for all Wikimedia projects and languages. The projects include Wikipedia, Wikibooks, Wikitionary, Wikinews, etc. They elected to
# [stop publishing that data](https://lists.wikimedia.org/pipermail/analytics/2016-March/005060.html) because it "does not count access to the
# mobile site, it does not filter out spider or bot traffic, and it suffers from unknown loss due to logging infrastructure limitations."
#
# However, the historical files are still out there, and they still make for an interesting use case. We'll be using the files from August 5, 2016 at 12:00 PM UTC. We've preloaded that data and converted it to a Parquet file for easy consumption.
#
# You can see the hourly dump files <a href="https://dumps.wikimedia.org/other/pagecounts-raw/" target="_blank">here</a>.

# %% [markdown]
# Each line in the pagecounts files contains 4 fields:
# - Project name
# - Page title
# - Number of requests the page recieved this hour
# - Total size in bytes of the content returned

# %% [markdown]
# ![Schema Explanation](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/schema_explanation.png)

# %% [markdown]
# In each line, the first column (like `en`) is the Wikimedia project name. The following abbreviations are used for the first column:
# ```
# wikipedia mobile: ".mw"
# wiktionary: ".d"
# wikibooks: ".b"
# wikimedia: ".m"
# wikinews: ".n"
# wikiquote: ".q"
# wikisource: ".s"
# wikiversity: ".v"
# mediawiki: ".w"
# ```
#
# Projects without a period and a following character are Wikipedia projects. So, any line starting with the column `en` refers to the English language Wikipedia (and can be requests from either a mobile or desktop client).
#
# There will only be one line starting with the column `en.mw`, which will have a total count of the number of requests to English language Wikipedia's mobile edition.
#
# `en.d` refers to English language Wiktionary.
#
# `fr` is French Wikipedia. There are over 290 language possibilities.

# %%
#dbutils = interage com camada S3
#databrics cria uma camada de filesystem (DBFS) para acessar o s3
#o comando baixo lista os arquivos no diretório staging_parquet_en_only
display( dbutils.fs.ls("/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/") )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/_common_metadata</td><td>_common_metadata</td><td>507</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/_metadata</td><td>_metadata</td><td>4682</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00000-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00000-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2988663</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00001-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00001-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2995436</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00002-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00002-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2990960</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00003-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00003-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2990647</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00004-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00004-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2998049</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00005-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00005-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2993458</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00006-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00006-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2991126</td></tr><tr><td>dbfs:/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/part-r-00007-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>part-r-00007-1a5154c5-19cd-420a-bb8e-11421faea7a6.gz.parquet</td><td>2995335</td></tr></tbody></table></div>

# %% [markdown]
# ####![Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/logo_spark_tiny.png) **Create a DataFrame**

# %% [markdown]
# A `spark` object is your entry point for working with structured data (rows and columns) in Spark.
#
# Let's use the `spark` to create a DataFrame from the most recent pagecounts file:

# %%
# Alimenta Dataframe com dados em parquet
pagecounts_en_all_df = spark.read.parquet('/mnt/wikipedia-readonly/pagecounts/staging_parquet_en_only/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Look at the first few records in the DataFrame:

# %%
pagecounts_en_all_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------+------------+
# project|             article|requests|bytes_served|
# +-------+--------------------+--------+------------+
#      en|        !!Fuck_you!!|       1|           0|
#      en|      !?Revolution!?|       1|           0|
#      en|!Alfaro_Vive,_Car...|       1|           0|
#      en|       !Ay,_caramba!|       1|           0|
#      en|            !DOCTYPE|       1|           0|
#      en|    !Gã!nge_language|       1|           0|
#      en|     !Hukwe_language|       1|           0|
#      en|           !Kung_San|       1|           0|
#      en|    !O!kung_language|       1|           0|
#      en|       !Ora_language|       1|           0|
#      en|           !T.O.O.H!|       1|           0|
#      en|               !Tre!|       1|           0|
#      en|       !Viva_Zapata!|       1|           0|
#      en|      !Xoon_language|       1|           0|
#      en|       !Xóõ_language|       2|           0|
#      en|  !_(disambiguation)|       3|           0|
#      en|             !llmind|       1|           0|
#      en|                   .|       1|           0|
#      en|...explosante-fix...|       1|           0|
#      en|   A_Little_Boy_Lost|       1|           0|
# +-------+--------------------+--------+------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# `printSchema()` prints out the schema for the DataFrame, the data types for each column and whether a column can be null:

# %%
# Parquet armazena schema dentro dele
pagecounts_en_all_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- project: string (nullable = true)
# -- article: string (nullable = true)
# -- requests: integer (nullable = true)
# -- bytes_served: long (nullable = true)
#
# </div>

# %% [markdown]
# Notice above that the first 2 columns are typed as `string`, but the requests column holds an `integer` and the bytes_served column holds a `long`.

# %% [markdown]
# Count the number of total records (rows) in the DataFrame:

# %%
pagecounts_en_all_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>2346733
# </div>

# %% [markdown]
# So, there are between 2 - 3 million rows in the DataFrame. This includes traffic to not just English Wikipedia articles, but also possibly English Wiktionary, Wikibooks, Wikinews, etc.

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-1) How many different English Wikimedia projects saw traffic during that hour?**

# %%
pagecounts_en_all_df.select('project').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+
#     project|
# +-----------+
#    en.m.voy|
#          en|
#   en.zero.n|
#        en.v|
#      en.m.v|
#        en.s|
#   en.zero.s|
#        en.n|
#   en.zero.d|
#      en.m.n|
#        en.m|
#      en.m.q|
#      en.m.s|
# en.zero.voy|
#        en.d|
#   en.zero.b|
#   en.zero.v|
#     en.zero|
#      en.m.b|
#        en.b|
# +-----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# You can see that `show()` is `only showing top 20 rows`. Let's fix this.
#
# How can we tell `show()` to display more lines?

# %% [markdown]
# **Challenge 1:**
# 1. Take a minute to look this up in the [Spark documentation](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.show).
# 2. Call `show()` on this DataFrame and set its parameter to display 50 lines

# %%
# TODO
pagecounts_en_all_df.select('project').distinct().show(50)
# Type your answer here...
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+
#     project|
# +-----------+
#    en.m.voy|
#          en|
#   en.zero.n|
#        en.v|
#      en.m.v|
#        en.s|
#   en.zero.s|
#        en.n|
#   en.zero.d|
#      en.m.n|
#        en.m|
#      en.m.q|
#      en.m.s|
# en.zero.voy|
#        en.d|
#   en.zero.b|
#   en.zero.v|
#     en.zero|
#      en.m.b|
#        en.b|
#      en.voy|
#   en.zero.q|
#      en.m.d|
#        en.q|
# +-----------+
#
# </div>

# %% [markdown]
# **Challenge 2: ** Can you figure out how to show 10 articles that saw traffic during that hour?

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-2) How much traffic did each English Wikimedia project get during that hour?**

# %% [markdown]
# The following command will show the total number of requests each English Wikimedia project received:

# %%
pagecounts_en_all_sum_df = (pagecounts_en_all_df.
    select('project', 'requests').             # transformation
    groupBy('project').                        # transformation
    sum().                                     # transformation. Se quiser usar uma coluna só, passar a coluna dentro do sum
    orderBy('sum(requests)', ascending=False). # transformation
    show()                                     # action
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-------------+
#   project|sum(requests)|
# +---------+-------------+
#        en|      6979861|
#      en.m|      4657472|
#   en.zero|       120666|
#      en.d|        61091|
#    en.m.d|        26733|
#      en.b|        17257|
#      en.q|         6984|
#    en.m.b|         6855|
#    en.m.q|         4178|
#      en.s|         3909|
#    en.voy|         2142|
#      en.v|         1884|
#    en.m.s|         1339|
#      en.n|          975|
#    en.m.v|          801|
#  en.m.voy|          708|
# en.zero.d|          564|
# en.zero.b|          434|
#    en.m.n|          207|
# en.zero.q|          113|
# +---------+-------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# English Wikipedia desktop (en) typically gets the highest number of requests, followed by English Wikipedia mobile (en.mw).

# %% [markdown]
# ####![Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/logo_spark_tiny.png) **Transformations and Actions**

# %% [markdown]
# ####![Spark Operations](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/spark_ta.png)

# %% [markdown]
# DataFrames support two types of operations: *transformations* and *actions*.
#
# Transformations, like `select()` or `filter()` create a new DataFrame from an existing one.
#
# Actions, like `show()` or `count()`, return a value with results to the user. Other actions like `save()` write the DataFrame to distributed storage (like S3 or HDFS).

# %% [markdown]
# ####![Spark T/A](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/trans_and_actions.png)

# %% [markdown]
# Transformations contribute to a query plan,  but  nothing is executed until an action is called.

# %% [markdown]
# Consider opening the <a href="https://spark.apache.org/docs/1.6.2/api/scala/index.html#org.apache.spark.sql.DataFrame" target="_blank">DataFrame API docs</a> in a new tab to keep it handy as a reference.
#
# You can also hit 'tab' after the DataFrame name to see a drop down of the available methods:

# %% [markdown]
# ####![tab](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/tab.png)

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-3) What were the 25 most popular English articles during the past hour?**

# %% [markdown]
# The `filter()` transformation can be used to filter a DataFrame where the language column is `en`, meaning English Wikipedia articles only:

# %%
# Only rows for for English Wikipedia (en) will pass this filter, removing projects like Wiktionary, Wikibooks, Wikinews, etc
pagecounts_en_wikipedia_df = pagecounts_en_all_df.filter(pagecounts_en_all_df['project'] == "en")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Notice above that transformations, like `filter()`, return back a DataFrame.

# %% [markdown]
# Next, we can use the `orderBy()` transformation on the requests column to order the requests in descending order:

# %%
# Order by the requests column, in descending order
pagecounts_en_wikipedia_df.orderBy('requests', ascending=False).show(25)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------+------------+
# project|             article|requests|bytes_served|
# +-------+--------------------+--------+------------+
#      en|           Main_Page|  865692|           0|
#      en|      Special:Search|   76231|           0|
#      en|               Midas|   55210|           0|
#      en|        Donald_Trump|   44640|           0|
#      en|                   -|   35663|           0|
#      en|Special:RecentCha...|   23419|           0|
#      en|             404.php|   20363|           0|
#      en|United_States_pre...|   19401|           0|
#      en|       Melania_Trump|   15220|           0|
#      en|Special:CreateAcc...|   11958|           0|
#      en|Electoral_College...|   11788|           0|
#      en|        Special:Book|   11523|           0|
#      en|United_States_pre...|   11267|           0|
#      en|               AMGTV|   10775|           0|
#      en|         Proyecto_40|    9723|           0|
#      en|United_States_pre...|    7481|           0|
#      en|        Ivanka_Trump|    7453|           0|
#      en|         Ivana_Trump|    6946|           0|
#      en|     Hillary_Clinton|    6538|           0|
#      en|        Marla_Maples|    6098|           0|
#      en|          Mike_Pence|    5950|           0|
#      en|        Barack_Obama|    5749|           0|
#      en|       René_Magritte|    5555|           0|
#      en|List_of_President...|    5507|           0|
#      en|United_States_pre...|    5321|           0|
# +-------+--------------------+--------+------------+
# only showing top 25 rows
#
# </div>

# %% [markdown]
# In Databricks, there is a special display function that displays a Dataframe in an HTML table:

# %%
# Display the DataFrame as an HTML table so it's easier to read.
most_popular_en_wikipedia_df = pagecounts_en_wikipedia_df.orderBy('requests', ascending=False).limit(25)
display(most_popular_en_wikipedia_df) #função da databrics
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en</td><td>Main_Page</td><td>865692</td><td>0</td></tr><tr><td>en</td><td>Special:Search</td><td>76231</td><td>0</td></tr><tr><td>en</td><td>Midas</td><td>55210</td><td>0</td></tr><tr><td>en</td><td>Donald_Trump</td><td>44640</td><td>0</td></tr><tr><td>en</td><td>-</td><td>35663</td><td>0</td></tr><tr><td>en</td><td>Special:RecentChangesLinked</td><td>23419</td><td>0</td></tr><tr><td>en</td><td>404.php</td><td>20363</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2016</td><td>19401</td><td>0</td></tr><tr><td>en</td><td>Melania_Trump</td><td>15220</td><td>0</td></tr><tr><td>en</td><td>Special:CreateAccount</td><td>11958</td><td>0</td></tr><tr><td>en</td><td>Electoral_College_(United_States)</td><td>11788</td><td>0</td></tr><tr><td>en</td><td>Special:Book</td><td>11523</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2012</td><td>11267</td><td>0</td></tr><tr><td>en</td><td>AMGTV</td><td>10775</td><td>0</td></tr><tr><td>en</td><td>Proyecto_40</td><td>9723</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2008</td><td>7481</td><td>0</td></tr><tr><td>en</td><td>Ivanka_Trump</td><td>7453</td><td>0</td></tr><tr><td>en</td><td>Ivana_Trump</td><td>6946</td><td>0</td></tr><tr><td>en</td><td>Hillary_Clinton</td><td>6538</td><td>0</td></tr><tr><td>en</td><td>Marla_Maples</td><td>6098</td><td>0</td></tr><tr><td>en</td><td>Mike_Pence</td><td>5950</td><td>0</td></tr><tr><td>en</td><td>Barack_Obama</td><td>5749</td><td>0</td></tr><tr><td>en</td><td>René_Magritte</td><td>5555</td><td>0</td></tr><tr><td>en</td><td>List_of_Presidents_of_the_United_States</td><td>5507</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2000</td><td>5321</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Hmm, the result doesn't look correct. The article column contains non-articles, like: `Special:`, `File:`, `Category:`, `Portal`, etc. Let's learn about Namespaces so we can filter the non-articles out...

# %% [markdown]
# ####![Wikipedia Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/logo_wikipedia_tiny.png) **Wikipedia Namespaces**

# %% [markdown]
# Wikipedia has many namespaces. The 5.1 million English articles are in the 0 namespace *(in red below)*. The other namespaces are for things like:
# - Wikipedian User profiles (`User:` namespace 2)
# - Files like images or videos (`File:` namespace 6)
# - Draft articles not yet ready for publishing (`Draft:` namespace 118)
#
# The hourly pagecounts file contains traffic requests to all Wikipedia namespaces. We'll need to filter out anything that is not an article.

# %% [markdown]
# ![namespaces](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/namespaces.png)
#
# Source: <a href="https://en.wikipedia.org/wiki/Wikipedia:Namespace" target="_blank">Wikipedia:Namespace</a>

# %% [markdown]
# For example, here is the `User:` page for Jimmy Wales, a co-founder of Wikipedia:
#
# ![User:jimbo_wales](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/user-jimbo_wales.png)
#
# Source: <a href="https://en.wikipedia.org/wiki/User:Jimbo_Wales" target="_blank">User:Jimbo_Wales</a>

# %% [markdown]
# Which is different from the normal article page for Jimmy Wales *(this is the encyclopedic one)*:
#
# ![article-jimmy_wales](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/article-jimmy_wales.png)
#
# Source: <a href="https://en.wikipedia.org/wiki/Jimmy_Wales" target="_blank">Jimmy_Wales<a/>

# %% [markdown]
# Next, here is an image from the `File:` namespace of Jimmy Wales in 2010:
#
# ![File:jimmy_wales_2010](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/pagecounts/file-jimmy_wales.png)
#
# Source: <a href="https://en.wikipedia.org/wiki/File:Jimmy_Wales_July_2010.jpg" target="_blank">File:Jimmy_Wales_July_2010.jpg</a>

# %% [markdown]
# Let's filter out everything that is not an article:

# %%
# The 17 filters will remove everything that is not an article

pagecounts_en_wikipedia_articles_only_df = (pagecounts_en_wikipedia_df
  .filter(pagecounts_en_wikipedia_df["article"].rlike(r'^((?!Special:)+)'))
  .filter(pagecounts_en_wikipedia_df["article"].rlike(r'^((?!File:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Category:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!User:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Talk:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Template:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Help:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Wikipedia:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!MediaWiki:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Portal:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Book:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Draft:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Education_Program:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!TimedText:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Module:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Topic:)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!Images/)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!%22//upload.wikimedia.org)+)'))
  .filter(pagecounts_en_wikipedia_df['article'].rlike(r'^((?!%22//en.wikipedia.org)+)'))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Finally, repeat the `orderBy()` transformation from earlier:

# %%
display(pagecounts_en_wikipedia_articles_only_df.orderBy('requests', ascending=False).limit(25))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en</td><td>Main_Page</td><td>865692</td><td>0</td></tr><tr><td>en</td><td>Midas</td><td>55210</td><td>0</td></tr><tr><td>en</td><td>Donald_Trump</td><td>44640</td><td>0</td></tr><tr><td>en</td><td>-</td><td>35663</td><td>0</td></tr><tr><td>en</td><td>404.php</td><td>20363</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2016</td><td>19401</td><td>0</td></tr><tr><td>en</td><td>Melania_Trump</td><td>15220</td><td>0</td></tr><tr><td>en</td><td>Electoral_College_(United_States)</td><td>11788</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2012</td><td>11267</td><td>0</td></tr><tr><td>en</td><td>AMGTV</td><td>10775</td><td>0</td></tr><tr><td>en</td><td>Proyecto_40</td><td>9723</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2008</td><td>7481</td><td>0</td></tr><tr><td>en</td><td>Ivanka_Trump</td><td>7453</td><td>0</td></tr><tr><td>en</td><td>Ivana_Trump</td><td>6946</td><td>0</td></tr><tr><td>en</td><td>Hillary_Clinton</td><td>6538</td><td>0</td></tr><tr><td>en</td><td>Marla_Maples</td><td>6098</td><td>0</td></tr><tr><td>en</td><td>Mike_Pence</td><td>5950</td><td>0</td></tr><tr><td>en</td><td>Barack_Obama</td><td>5749</td><td>0</td></tr><tr><td>en</td><td>René_Magritte</td><td>5555</td><td>0</td></tr><tr><td>en</td><td>List_of_Presidents_of_the_United_States</td><td>5507</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2000</td><td>5321</td><td>0</td></tr><tr><td>en</td><td>Tiffany_Trump</td><td>5216</td><td>0</td></tr><tr><td>en</td><td>Mean_world_syndrome</td><td>4583</td><td>0</td></tr><tr><td>en</td><td>Donald_Trump_Jr.</td><td>4488</td><td>0</td></tr><tr><td>en</td><td>United_States_presidential_election,_2004</td><td>4208</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# That looks better. Above you are seeing the 25 most requested English Wikipedia articles in the past hour!
#
# This can give you a sense of what's popular or trending on the planet right now.

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-4) How many requests did the "Apache Spark" article receive during this hour? **

# %% [markdown]
# **Challenge 3: ** Can you figure out how to filter the `pagecountsEnWikipediaArticlesOnlyDF` DataFrame for just `Apache_Spark`?

# %%
# TODO
# Type your answer here.
pagecounts_en_wikipedia_articles_only_df.filter(pagecounts_en_wikipedia_articles_only_df['article'] == 'Apache_Spark').show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------+--------+------------+
# project|     article|requests|bytes_served|
# +-------+------------+--------+------------+
#      en|Apache_Spark|      71|           0|
# +-------+------------+--------+------------+
#
# </div>

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-5) Which Apache project received the most requests during this hour? **

# %%
# In the Regular Expression below:
# ^  - Matches beginning of line
# .* - Matches any characters, except newline

(pagecounts_en_wikipedia_articles_only_df
  .filter(pagecounts_en_wikipedia_articles_only_df["article"].rlike("""^Apache_.*"""))
  .orderBy('requests', ascending=False)
  .show() # By default, show will return 20 rows
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------+------------+
# project|             article|requests|bytes_served|
# +-------+--------------------+--------+------------+
#      en|       Apache_Hadoop|     168|           0|
#      en|        Apache_Spark|      71|           0|
#      en|       Apache_Tomcat|      56|           0|
#      en|  Apache_HTTP_Server|      52|           0|
#      en|      Apache_License|      40|           0|
#      en|        Apache_Maven|      39|           0|
#      en|    Apache_Cassandra|      38|           0|
#      en|        Apache_Kafka|      34|           0|
#      en|         Apache_Hive|      32|           0|
#      en|      Apache_Cordova|      29|           0|
#      en|         Apache_Solr|      23|           0|
#      en|    Apache_ZooKeeper|      21|           0|
#      en|     Apache_ActiveMQ|      18|           0|
#      en|        Apache_Mesos|      18|           0|
#      en|Apache_Software_F...|      17|           0|
#      en|        Apache_HBase|      14|           0|
#      en|   Apache_OpenOffice|      14|           0|
#      en|          Apache_Ant|      13|           0|
#      en|         Apache_Axis|      12|           0|
#      en|        Apache_Axis2|      11|           0|
# +-------+--------------------+--------+------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-6) What percentage of the 5.1 million English articles were requested during the hour?**

# %% [markdown]
# Start with the DataFrame that has already been filtered and contains just the English Wikipedia Articles:

# %%
display(pagecounts_en_wikipedia_articles_only_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en</td><td>!!Fuck_you!!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!?Revolution!?</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Alfaro_Vive,_Carajo!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Ay,_caramba!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!DOCTYPE</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Gã!nge_language</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Hukwe_language</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Kung_San</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!O!kung_language</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Ora_language</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!T.O.O.H!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Tre!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Viva_Zapata!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Xoon_language</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Xóõ_language</td><td>2</td><td>0</td></tr><tr><td>en</td><td>!_(disambiguation)</td><td>3</td><td>0</td></tr><tr><td>en</td><td>!llmind</td><td>1</td><td>0</td></tr><tr><td>en</td><td>.</td><td>1</td><td>0</td></tr><tr><td>en</td><td>...explosante-fixe...</td><td>1</td><td>0</td></tr><tr><td>en</td><td>A_Little_Boy_Lost</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Allan_Kournikova</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Bartolo_Alvarez</td><td>1</td><td>0</td></tr><tr><td>en</td><td>$</td><td>1</td><td>0</td></tr><tr><td>en</td><td>$9.99</td><td>5</td><td>0</td></tr><tr><td>en</td><td>%</td><td>1</td><td>0</td></tr><tr><td>en</td><td>'03_Bonnie_&_Clyde</td><td>2</td><td>0</td></tr><tr><td>en</td><td>'71</td><td>1</td><td>0</td></tr><tr><td>en</td><td>'Abd_al-Ahad_Khan</td><td>1</td><td>0</td></tr><tr><td>en</td><td>'Allo_'Allo!</td><td>53</td><td>0</td></tr><tr><td>en</td><td>'And'_theory_of_conservatism</td><td>1</td><td>0</td></tr><tr><td>en</td><td>'Atara</td><td>5</td><td>0</td></tr><tr><td>en</td><td>'Moteng</td><td>2</td><td>0</td></tr><tr><td>en</td><td>'Neath_the_Arizona_Skies</td><td>2</td><td>0</td></tr><tr><td>en</td><td>'S_Wonderful</td><td>2</td><td>0</td></tr><tr><td>en</td><td>'The_Crusader_(publication)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>'Til_We_Meet_Again</td><td>2</td><td>0</td></tr><tr><td>en</td><td>'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-John_album)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>'s-Heerenberg</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(-)-menthol_dehydrogenase</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(202421)_2005_UQ513</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(3-Aminopropyl)triethoxysilane</td><td>5</td><td>0</td></tr><tr><td>en</td><td>(386454)_2008_XM</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(Benzene)chromium_tricarbonyl</td><td>3</td><td>0</td></tr><tr><td>en</td><td>(Everything_I_Do)_I_Do_It_for_You</td><td>5</td><td>0</td></tr><tr><td>en</td><td>(How_to_Be_a)_Millionaire</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(I'm_in_Love_with)_a_Wonderful_Guy</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(I_Just)_Died_in_Your_Arms</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(Irish)_Repeal</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(Much)_Wenlock_(UK_Parliament_constituency)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(R)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(R)-pantolactone_dehydrogenase_(flavin)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(S)-2-hydroxy-acid_oxidase</td><td>1</td><td>0</td></tr><tr><td>en</td><td>(S)-methylmalonyl-CoA_hydrolase</td><td>2</td><td>0</td></tr><tr><td>en</td><td>(Sittin'_On)_The_Dock_of_the_Bay</td><td>3</td><td>0</td></tr><tr><td>en</td><td>(They_Long_to_Be)_Close_to_You</td><td>9</td><td>0</td></tr><tr><td>en</td><td>(What's_the_Story)_Morning_Glory?</td><td>24</td><td>0</td></tr><tr><td>en</td><td>(You_Dr ...

# %% [markdown]
# Call the `count()` action on the DataFrame to see how many unique English articles were requested in the last hour:

# %%
pagecounts_en_wikipedia_articles_only_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>1263540
# </div>

# %% [markdown]
# The `count()` action returns back a `Long` data type in Scala and an `int` in Python.

# %% [markdown]
# There are currently about 5.1 million articles in English Wikipedia. So the percentage of English articles requested in the past hour is:

# %%
(pagecounts_en_wikipedia_articles_only_df.count() / 5100000.0) * 100
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>24.77529411764706
# </div>

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-7) How many total requests were there to English Wikipedia Desktop edition?**

# %% [markdown]
# The DataFrame holding English Wikipedia article requests has a 3rd column named `requests`:

# %%
pagecounts_en_wikipedia_articles_only_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- project: string (nullable = true)
# -- article: string (nullable = true)
# -- requests: integer (nullable = true)
# -- bytes_served: long (nullable = true)
#
# </div>

# %% [markdown]
# If we `groupBy()` the project column and then call `sum()`, we can count how many total requests there were to English Wikipedia:

# %%
# Import the SQL functions package, which includes statistical functions like sum(), max(), min(), avg(), etc.
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(pagecounts_en_wikipedia_df.groupBy("project").sum())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>sum(requests)</th><th>sum(bytes_served)</th></tr></thead><tbody><tr><td>en</td><td>6979861</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ####![Wikipedia + Spark Logo Tiny](http://curriculum-release.s3-website-us-west-2.amazonaws.com/wiki-book/general/wiki_spark_small.png) **Q-8) How many total requests were there to English Wikipedia Mobile edition?**

# %% [markdown]
# We'll need to start with the original, base DataFrame, which contains all the English Wikimedia project requests:

# %%
display(pagecounts_en_all_df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en</td><td>!!Fuck_you!!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!?Revolution!?</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Alfaro_Vive,_Carajo!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!Ay,_caramba!</td><td>1</td><td>0</td></tr><tr><td>en</td><td>!DOCTYPE</td><td>1</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# **Challenge 4**: Set the table for answering this business question:
# 1. First Run a `filter()` to keep just the rows referring to English Mobile. The mobile edition articles have the `project` column set to `en.m`.
# 2. Count the rows in the resulting DataFrame

# %%
# TODO
# Filtra Mobile Edition
pagecounts_en_mobile_df = pagecounts_en_all_df.filter(pagecounts_en_all_df['project'] == 'en.m')
# Conta ocorrências
pagecounts_en_mobile_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>808319
# </div>

# %%
pagecounts_en_mobile_df = pagecounts_en_all_df.filter(pagecounts_en_all_df['project'] == 'en.m')
pagecounts_en_mobile_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>808319
# </div>

# %% [markdown]
# Okay, what do we have?

# %%
display(pagecounts_en_mobile_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en.m</td><td>!Hero</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>$1000</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>%s</td><td>18</td><td>0</td></tr><tr><td>en.m</td><td>'57_Chevy</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>'Abd_al-Rahman_ibn_'Awf</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>'Are'are_people</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>'Ndrangheta</td><td>7</td><td>0</td></tr><tr><td>en.m</td><td>'Sang_Linggo_nAPO_Sila</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>'Till_I_Collapse</td><td>7</td><td>0</td></tr><tr><td>en.m</td><td>'Ujayf_ibn_'Anbasa</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(101955)_1999_RQ36</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(87269)_2000_OO67</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(Everything_I_Do)_I_Do_It_for_You</td><td>11</td><td>0</td></tr><tr><td>en.m</td><td>(I'll_Never_Be)_Maria_Magdalena</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(I_Just)_Died_in_Your_Arms</td><td>6</td><td>0</td></tr><tr><td>en.m</td><td>(Lay_Your_Head_on_My)_Pillow</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(Ribulose-bisphosphate_carboxylase)-lysine_N-methyltransferase</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(Up_A)_Lazy_River</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>(White_Man)_In_Hammersmith_Palais</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>(Your_Love_Keeps_Lifting_Me)_Higher_and_Higher</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>*</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>+387</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>+90</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>,</td><td>4</td><td>0</td></tr><tr><td>en.m</td><td>-graphy</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>-nik</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>...And_Justice_for_All_(film)</td><td>5</td><td>0</td></tr><tr><td>en.m</td><td>...Best_II</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>...Nothing_Like_the_Sun</td><td>3</td><td>0</td></tr><tr><td>en.m</td><td>..._Not!</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>.17_Hornet</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.219_Zipper</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.223_Remington</td><td>24</td><td>0</td></tr><tr><td>en.m</td><td>.22_LR</td><td>3</td><td>0</td></tr><tr><td>en.m</td><td>.22_caliber</td><td>5</td><td>0</td></tr><tr><td>en.m</td><td>.250_Savage</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.270_Winchester_Short_Magnum</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.30-06</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.300_H&H_Magnum</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>.300_Winchester_Magnum</td><td>24</td><td>0</td></tr><tr><td>en.m</td><td>.308_Winchester</td><td>23</td><td>0</td></tr><tr><td>en.m</td><td>.325_Winchester_Short_Magnum</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.338_Lapua</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.33_Winchester</td><td>4</td><td>0</td></tr><tr><td>en.m</td><td>.35_Remington</td><td>7</td><td>0</td></tr><tr><td>en.m</td><td>.38</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>.38_S&W</td><td>3</td><td>0</td></tr><tr><td>en.m</td><td>.408_Cheyenne_Tactical</td><td>3</td><td>0</td></tr><tr><td>en.m</td><td>.41_Short</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.45-70</td><td>22</td><td>0</td></tr><tr><td>en.m</td><td>.458_Winchester_Magnum</td><td>5</td><td>0</td></tr><tr><td>en.m</td><td>.460_Rowland</td><td>3</td><td>0</td></tr><tr><td>en.m</td><td>.50-90_Sharps</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.577/450_Martini–Henry</td><td>4</td><td>0</td></tr><tr><td>en.m</td><td>.Exe</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.aeDA</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>.at</td><td>1</td><td>0</td></tr><tr><td>en.m< ...

# %% [markdown]
# Let's aggregate.

# %%
display(pagecounts_en_mobile_df.select(sum(pagecounts_en_mobile_df['requests'])))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(requests)</th></tr></thead><tbody><tr><td>4657472</td></tr></tbody></table></div>

# %% [markdown]
# The requests column above displays how many total requests English Wikipedia got from mobile clients. About 50% of the traffic to English Wikipedia seems to come from mobile clients.

# %% [markdown]
# We will analyze the Mobile vs. Desktop traffic patterns to Wikipedia more in the next notebook.
